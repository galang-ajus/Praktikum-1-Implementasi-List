# %% [markdown]
# <a href="https://colab.research.google.com/github/galang-ajus/Praktikum-1-Implementasi-List/blob/main/Praktikum_1_%E2%80%93_Implementasi_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = []

# input 10 angka
for i in range(10):
    angka = int(input("Masukkan angka: "))
    arr.append(angka)

print("Array:", arr)
print("Nilai maksimum:", max(arr))
print("Nilai minimum:", min(arr))
print("Rata-rata:", sum(arr)/len(arr))
# Out:
# Masukkan angka: 3
# Masukkan angka: 4
# Masukkan angka: 1
# Masukkan angka: 6
# Masukkan angka: 7
# Masukkan angka: 9
# Masukkan angka: 10
# Masukkan angka: 4
# Masukkan angka: 8
# Masukkan angka: 2
# Array: [3, 4, 1, 6, 7, 9, 10, 4, 8, 2]
# Nilai maksimum: 10
# Nilai minimum: 1
# Rata-rata: 5.4
